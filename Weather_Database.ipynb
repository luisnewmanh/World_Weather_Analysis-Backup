# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from API_key import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Create counters.
record_count = 1
set_count = 1
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Beginning Data Retrieval      ")
print("-----------------------------")
# Loop through all the cities in the list. With enumerate you get index and element at the same time!!!
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_dictionary = city_weather['weather'][0]
        city_description = weather_dictionary["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_description})

        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 5 of Set 1 | palabuhanratu
# Processing Record 6 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 7 of Set 1 | stoyba
# Processing Record 8 of Set 1 | portland
# Processing Record 9 of Set 1 | celestun
# Processing Record 10 of Set 1 | wadi musa
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | travnik
# Processing Record 13 of Set 1 | darnah
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 17 of Set 1 | inderborskiy
# Processing Record 18 of Set 1 | udarnyy
# Processing Record 19 of Set 1 | port alfred
# ...

# %%
print(len(city_data))
#print(city_url)
#city_weather = requests.get(city_url).json()
#weather_dictionary = city_weather['weather'][0]
#print(type(weather_dictionary))
#print(weather_dictionary['description'])
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Jamestown  42.10  -79.24     54.00        70          40       10.29
# 1   Khatanga  71.97  102.50     22.55        97         100       17.60
# 2      Vaini -21.20 -175.20     71.60       100          90       12.75
# 3     Atuona  -9.80 -139.03     77.05        75           0       19.73
# 4      Bluff -46.60  168.33     44.01        97          89        8.72
# 5   Portland  45.52 -122.68     59.00        87          90        6.93
# 6   Celestun  20.87  -90.40     79.59        84         100       24.70
# 7  Wadi Musa  30.32   35.48     68.47        46           0        8.70
# 8     Torbay  47.67  -52.73     53.01        76          75       14.99
# 9    Travnik  44.23   17.67     77.00        31           0        8.05
#
#   Country          Current Description
# 0      US             scattered clouds
# 1      RU              overcast clouds
# 2      TO  light intensity shower rain
# ...

# %%
# Rearrange columns
#City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
city_data_df=new_city_data_df
city_data_df.head()
# Out:
#         City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Jamestown      US  42.10  -79.24     54.00        70          40
# 1   Khatanga      RU  71.97  102.50     22.55        97         100
# 2      Vaini      TO -21.20 -175.20     71.60       100          90
# 3     Atuona      PF  -9.80 -139.03     77.05        75           0
# 4      Bluff      NZ -46.60  168.33     44.01        97          89
#
#    Wind Speed          Current Description
# 0       10.29             scattered clouds
# 1       17.60              overcast clouds
# 2       12.75  light intensity shower rain
# 3       19.73                    clear sky
# 4        8.72              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database.csv")
